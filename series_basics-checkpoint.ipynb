# %%
import os
import pandas as pd 
dir="C:\\Users\\Tharun\\Downloads\\titanic"
titanic=pd.read_csv(os.path.join(dir,'train.csv'));
print(titanic)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#print(titanic.iloc[0:4]) # 4 rows -- 0th row to 3rd row 
#print(titanic.iloc[1:4]) # 3 rows i.e from 1 to 3
#print(titanic.iloc[0:3,0:3]) # 3 rows and 3 columns 
#print(titanic.iloc[[1,3],[0,2]]) # if we want to specify columns and rows 
print(titanic[titanic.Pclass==3])
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
#using loc on titanic data 
#print(titanic.loc[0:10])
#rint(titanic.loc[1:3,['Pclass','Sex']])
#pint(titanic.loc[:10,['Pclass','Sex','Embarked']])
#print(titanic.loc[:10,'Pclass':'Fare'])
print(titanic.loc[titanic.Sex=='male',['Pclass','Sex','Embarked']])
# Out:
#      Pclass   Sex Embarked
# 0         3  male        S
# 4         3  male        S
# 5         3  male        Q
# 6         1  male        S
# 7         3  male        S
# ..      ...   ...      ...
# 883       2  male        S
# 884       3  male        S
# 886       2  male        S
# 889       1  male        C
# 890       3  male        Q
#
# [577 rows x 3 columns]

# %%
titanic1=titanic.loc[((titanic.Sex=='male') & (titanic.Pclass==1)), ['Pclass','Sex','Fare']]
titanic1
# Out:
#      Pclass   Sex      Fare
# 6         1  male   51.8625
# 23        1  male   35.5000
# 27        1  male  263.0000
# 30        1  male   27.7208
# 34        1  male   82.1708
# ..      ...   ...       ...
# 839       1  male   29.7000
# 857       1  male   26.5500
# 867       1  male   50.4958
# 872       1  male    5.0000
# 889       1  male   30.0000
#
# [122 rows x 3 columns]

# %%
titanic['new']='dummy'
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
